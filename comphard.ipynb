# %%
import pandas as pd

# %%
df=pd.read_csv("C:/Users/Ibscai36.DGVC-MCA/Documents/comphard.csv")
df.head()
# Out:
#   VendorName  ModelName   MYCT    MMIN     MMAX   CACH  CHMIN  CHMAX    PRP  \
# 0     adviser     32/60  125.0   256.0   6000.0  256.0   16.0  128.0  198.0
# 1      amdahl    470v/7   29.0  8000.0      NaN   32.0    8.0   32.0  269.0
# 2      amdahl   470v/7a   29.0  8000.0  32000.0   32.0    8.0   32.0  220.0
# 3      amdahl   470v/7b   29.0  8000.0  32000.0   32.0    8.0   32.0  172.0
# 4      amdahl   470v/7c   29.0  8000.0  16000.0   32.0    8.0   16.0  132.0
#
#      ERP
# 0    NaN
# 1  253.0
# 2  253.0
# 3  253.0
# 4  132.0

# %%
df.isnull()
# Out:
#      VendorName   ModelName   MYCT   MMIN   MMAX   CACH  CHMIN  CHMAX    PRP  \
# 0          False      False  False  False  False  False  False  False  False
# 1          False      False  False  False   True  False  False  False  False
# 2          False      False  False  False  False  False  False  False  False
# 3          False      False  False  False  False  False  False  False  False
# 4          False      False  False  False  False  False  False  False  False
# ..           ...        ...    ...    ...    ...    ...    ...    ...    ...
# 204        False      False  False  False  False  False  False  False  False
# 205        False      False  False  False  False  False  False   True  False
# 206        False      False  False  False   True  False  False  False  False
# 207        False      False  False  False  False  False   True  False  False
# 208        False      False  False   True  False  False  False  False  False
#
#        ERP
# 0     True
# 1    False
# ...

# %%
df.isnull().sum()
# Out:
# VendorName      0
# ModelName       0
# MYCT            7
# MMIN            9
# MMAX           12
# CACH            6
# CHMIN           9
# CHMAX           8
# PRP             8
# ERP             7
# dtype: int64

# %%
df.fillna(0)
# Out:
#     VendorName       ModelName   MYCT    MMIN     MMAX   CACH  CHMIN  CHMAX  \
# 0       adviser          32/60  125.0   256.0   6000.0  256.0   16.0  128.0
# 1        amdahl         470v/7   29.0  8000.0      0.0   32.0    8.0   32.0
# 2        amdahl        470v/7a   29.0  8000.0  32000.0   32.0    8.0   32.0
# 3        amdahl        470v/7b   29.0  8000.0  32000.0   32.0    8.0   32.0
# 4        amdahl        470v/7c   29.0  8000.0  16000.0   32.0    8.0   16.0
# ..          ...            ...    ...     ...      ...    ...    ...    ...
# 204      sperry           80/8  124.0  1000.0   8000.0    0.0    1.0    8.0
# 205      sperry  90/80-model-3   98.0  1000.0   8000.0   32.0    2.0    0.0
# 206      sratus             32  125.0  2000.0      0.0    0.0    2.0   14.0
# 207        wang         vs-100  480.0   512.0   8000.0   32.0    0.0    0.0
# 208        wang          vs-90  480.0     0.0   4000.0    0.0    0.0    0.0
#
#        PRP    ERP
# 0    198.0    0.0
# ...

# %%
mn=df['CHMIN'].mean()
mn
# Out:
# np.float64(4.705)

# %%
df['CHMIN']=df['CHMIN'].fillna(mn)
df.isnull().sum()
# Out:
# VendorName      0
# ModelName       0
# MYCT            7
# MMIN            9
# MMAX           12
# CACH            6
# CHMIN           0
# CHMAX           8
# PRP             8
# ERP             7
# dtype: int64

# %%
md=df['MYCT'].median()
md
# Out:
# 111.0

# %%
df['MYCT']=df['MYCT'].fillna(md)
df.isnull().sum()
# Out:
# VendorName      0
# ModelName       0
# MYCT            0
# MMIN            9
# MMAX           12
# CACH            6
# CHMIN           0
# CHMAX           8
# PRP             8
# ERP             7
# dtype: int64

# %%
ms=df['MMIN'].mode()
ms
# Out:
# 0    2000.0
# Name: MMIN, dtype: float64

# %%
df['MMIN']=df['MMIN'].fillna(md)
df.isnull().sum()
# Out:
# VendorName      0
# ModelName       0
# MYCT            0
# MMIN            0
# MMAX           12
# CACH            6
# CHMIN           0
# CHMAX           8
# PRP             8
# ERP             7
# dtype: int64

# %%
df['CACH']=df['CACH'].bfill()
df.isnull().sum()
# Out:
# VendorName      0
# ModelName       0
# MYCT            0
# MMIN            0
# MMAX           12
# CACH            0
# CHMIN           0
# CHMAX           8
# PRP             8
# ERP             7
# dtype: int64

# %%
df['CHMAX']=df['CHMAX'].ffill()
df.isnull().sum()
# Out:
# VendorName      0
# ModelName       0
# MYCT            0
# MMIN            0
# MMAX           12
# CACH            0
# CHMIN           0
# CHMAX           0
# PRP             8
# ERP             7
# dtype: int64

# %%
df['PRP']=df['PRP'].ffill()
df.isnull().sum()
# Out:
# VendorName      0
# ModelName       0
# MYCT            0
# MMIN            0
# MMAX           12
# CACH            0
# CHMIN           0
# CHMAX           0
# PRP             0
# ERP             7
# dtype: int64

# %%
df['ERP']=df['ERP'].ffill()
df.isnull().sum()
# Out:
# VendorName      0
# ModelName       0
# MYCT            0
# MMIN            0
# MMAX           12
# CACH            0
# CHMIN           0
# CHMAX           0
# PRP             0
# ERP             1
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
x=df['MMIN']
y=df['MMAX']
plt.title("COMPUTER HARDWARE")
plt.plot(x,y,color='purple',linestyle='dashdot',linewidth=3,marker='v',markerfacecolor='blue',markersize=13)
plt.show()
